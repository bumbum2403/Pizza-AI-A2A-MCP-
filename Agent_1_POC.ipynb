# %% [markdown]
# Let's build the Fast API for ordering first that our first agent will use.

# %%
# %pip install "fastapi[standard]"
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 629.1/629.1 kB 14.0 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 16.0 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 820.4/820.4 kB 13.7 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 15.7 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40/40 [fastapi-cli] [fastapi]e]t-py]
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# THe entire ordering and menu related information will be provided to the agent from the Fast API server running inside the /app folder. It contains a Pydantic Schema as well for providing mapping context to the LLM . Now we can access the server's API specs at
#
# ```
# uvicorn app.main:app --reload
# # and then head to
# http://127.0.0.1:8000/openapi.json
#
# ```
